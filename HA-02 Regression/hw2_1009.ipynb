# %% [markdown]
# Part1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
class LinearRegression:
    def __init__(self, n_feature = 1, lr=1e-4, epoch=10000, batch_size=10, tol = 1e-5):
        self.lr = lr  # 学习率
        self.epoch = epoch    # 迭代次数
        self.batch_size = batch_size        # 批量大小
        self.tol = tol          # 收敛阈值
        self.W = np.random.randn(n_feature + 1) * 0.05     # 权重
        self.losses = []

    def fit(self, X, y):
        X = np.c_[X, np.ones(X.shape[0])]  # 添加一列全为1的列作为偏置
        for i in range(self.epoch):
            # self._sgd_update(X, y)
            # self._bgd_update(X, y)
            self._sgd_update(X, y)
            if i % 100 == 0:
                loss = self._mse_loss(y, np.dot(X,self.W))
                self.losses.append(loss)
                print(f"for {i} iteration, the loss is {loss}")
        return self.W

    def _predict(self, X):
        return X @ self.W 

    def _mse_loss(self, y_true, y_pred):
        return ((y_true - y_pred) ** 2).mean()  # 计算均方误差损失

    def _gradient(self, X, y, y_pred):
        if isinstance(y, np.ndarray):
            delta_y = (y_pred-y).reshape((y.shape[0], 1))
            return np.mean(2 * delta_y.T @ X)
        else:
            delta_y = y_pred-y
            return (2 * delta_y.T * X).reshape((self.W.shape[0]))

    def _sgd_update(self, X, y):
        pred = self._predict(X)
        i = np.random.randint(0, len(X))
        grad = self._gradient( X[i,:][np.newaxis, :], y[i], pred[i])
        self.W -= self.lr * grad  # 随机梯度下降更新

    def _bgd_update(self, X, y): 
        pred = self._predict(X)
        grad = self._gradient(X, y, pred)
        self.W -= self.lr * grad  # 批量梯度下降更新
        
    def _mbgd_update(self, X, y):
        pred = self._predict(X)
        indices = np.random.choice(y.shape[0], self.batch_size, replace=False)
        # grad = np.zeros(self.W.shape[0])
        # for i in indices:
        #     grad += self._gradient(X[i], y[i], pred[i])
        grad = self._gradient(X[indices], y[indices], pred[indices])
        self.W -= self.lr * grad/self.batch_size

    def min_max_normalization(self, X):
        return (X - X.min(axis=0)) / (X.max(axis=0) - X.min(axis=0))  # 最小-最大归一化

    def mean_normalization(self, X):
        return (X - X.mean(axis=0))  # 均值归一化

# %% [markdown]
# Part2

# %%
X_train = np.arange(100).reshape(100,1)
a, b = 1, 10
y_train = a * X_train + b + np.random.normal(0, 5, size=X_train.shape)
y_train = y_train.reshape(-1)

# %% [markdown]
# 画出线性回归拟合后的曲线

# %%
model = LinearRegression(n_feature=X_train.shape[1])
w = model.fit(X_train, y_train)
plt.scatter(X_train[:, 0], y_train, color='blue', label='Training data')

x_values = np.linspace(X_train[:, 0].min(), X_train[:, 0].max(), num=100)
y_values = w[0] + w[1] * x_values
plt.plot(x_values, y_values, color='red', label='Linear regression')
plt.xlim([0, 100])
plt.ylim([0, 100])
plt.xlabel('X_train')
plt.ylabel('y_train')
plt.legend()
plt.title('Linear Regression')
plt.show()
# Out:
# for 0 iteration, the loss is 3253.007907727075
# for 100 iteration, the loss is 231.17846155920975
# for 200 iteration, the loss is 47.33226660882595
# for 300 iteration, the loss is 47.05511252518905
# for 400 iteration, the loss is 46.64592172259982
# for 500 iteration, the loss is 68.5506484922966
# for 600 iteration, the loss is 81.17597497963608
# for 700 iteration, the loss is 51.95232538446825
# for 800 iteration, the loss is 49.204932782779395
# for 900 iteration, the loss is 88.54078831329481
# for 1000 iteration, the loss is 49.29235427529926
# for 1100 iteration, the loss is 45.55007407975545
# for 1200 iteration, the loss is 103.24459762740452
# for 1300 iteration, the loss is 45.551018349151946
# for 1400 iteration, the loss is 66.82774389848971
# for 1500 iteration, the loss is 45.06800276981496
# for 1600 iteration, the loss is 84.02383384769082
# for 1700 iteration, the loss is 45.09266516368734
# for 1800 iteration, the loss is 116.41910502828178
# for 1900 iteration, the loss is 108.16582434714428
# for 2000 iteration, the loss is 128.35025636581878
# for 2100 iteration, the loss is 44.47992133319391
# for 2200 iteration, the loss is 50.60953154123277
# for 2300 iteration, the loss is 51.517621648812735
# for 2400 iteration, the loss is 44.447803102584395
# for 2500 iteration, the loss is 110.83783075310365
# for 2600 iteration, the loss is 47.99698098482398
# for 2700 iteration, the loss is 110.2289320654102
# for 2800 iteration, the loss is 63.09434992254697
# for 2900 iteration, the loss is 47.21435028379331
# for 3000 iteration, the loss is 104.79350314986806
# for 3100 iteration, the loss is 62.71919530717096
# for 3200 iteration, the loss is 93.43947678859482
# for 3300 iteration, the loss is 46.58657766702747
# for 3400 iteration, the loss is 42.909233749805324
# for 3500 iteration, the loss is 67.89064292698758
# for 3600 iteration, the loss is 158.44294739833566
# for 3700 iteration, the loss is 80.80034129746869
# for 3800 iteration, the loss is 67.1890913936553
# for 3900 iteration, the loss is 42.04412700580253
# for 4000 iteration, the loss is 56.51859447358386
# for 4100 iteration, the loss is 98.30802377148231
# for 4200 iteration, the loss is 119.98872744216999
# for 4300 iteration, the loss is 99.30395189130837
# for 4400 iteration, the loss is 45.782073953984664
# for 4500 iteration, the loss is 73.86904088674979
# for 4600 iteration, the loss is 52.33945851256584
# for 4700 iteration, the loss is 46.28237275771361
# for 4800 iteration, the loss is 41.45397979059944
# for 4900 iteration, the loss is 53.6395822159066
# for 5000 iteration, the loss is 52.935502647641854
# for 5100 iteration, the loss is 85.05976616488383
# for 5200 iteration, the loss is 53.15642699106451
# for 5300 iteration, the loss is 41.13794879952239
# for 5400 iteration, the loss is 55.74100826008802
# for 5500 iteration, the loss is 112.67989551719074
# for 5600 iteration, the loss is 41.847908328028545
# for 5700 iteration, the loss is 78.4964578032905
# for 5800 iteration, the loss is 42.11819872509782
# for 5900 iteration, the loss is 68.7693558766846
# for 6000 iteration, the loss is 103.57251620780607
# for 6100 iteration, the loss is 58.734681328685156
# for 6200 iteration, the loss is 39.62887218173654
# for 6300 iteration, the loss is 363.53324343722784
# for 6400 iteration, the loss is 48.23289555049053
# for 6500 iteration, the loss is 83.83440519245306
# for 6600 iteration, the loss is 66.0056665041909
# for 6700 iteration, the loss is 211.55937676359036
# for 6800 iteration, the loss is 38.536132690019336
# for 6900 iteration, the loss is 113.93279192258179
# for 7000 iteration, the loss is 118.65054726674636
# for 7100 iteration, the loss is 38.50401547170749
# for 7200 iteration, the loss is 42.47152968774303
# for 7300 iteration, the loss is 41.08027728433376
# for 7400 iteration, the loss is 39.75383795983122
# for 7500 iteration, the loss is 41.86280416164797
# for 7600 iteration, the loss is 38.44611813927845
# for 7700 iteration, the loss is 84.33139847658333
# for 7800 iteration, the loss is 40.345238571378644
# for 7900 iteration, the loss is 64.1966802176044
# for 8000 iteration, the loss is 37.118134153647595
# for 8100 iteration, the loss is 82.32590842832003
# for 8200 iteration, the loss is 37.62386484898126
# for 8300 iteration, the loss is 41.325214113124105
# for 8400 iteration, the loss is 128.63141706377107
# for 8500 iteration, the loss is 45.781819232897625
# for 8600 iteration, the loss is 62.26014315128438
# for 8700 iteration, the loss is 43.82035451596117
# for 8800 iteration, the loss is 54.603626666710724
# for 8900 iteration, the loss is 36.63246798248893
# for 9000 iteration, the loss is 39.23988761147019
# for 9100 iteration, the loss is 37.593276203286
# for 9200 iteration, the loss is 37.25722920800291
# for 9300 iteration, the loss is 85.34046354697473
# for 9400 iteration, the loss is 38.649247372811814
# for 9500 iteration, the loss is 57.02125043063348
# for 9600 iteration, the loss is 50.4011779773552
# for 9700 iteration, the loss is 84.86405960445519
# for 9800 iteration, the loss is 42.45258093199572
# for 9900 iteration, the loss is 48.57121654444727

# %% [markdown]
# 画出loss

# %%
epoches = np.linspace(0, model.epoch, num=100)
los = model.losses
plt.plot(epoches, los, label='loss')
plt.xlabel('epoches')
plt.ylabel('loss')
plt.legend()
plt.title('loss')
plt.show()
